# %%
import requests
import json

# %%
ip_address = "http://192.168.43.150:8080/sensors.json"

# %%
response = requests.get(ip_address)

# %%
sensor_info = response.json()

# %%
sensor_info.keys()
# Out:
# dict_keys(['accel', 'mag', 'gyro', 'light', 'proximity', 'gravity', 'lin_accel', 'rot_vector', 'battery_voltage', 'battery_level', 'battery_temp'])

# %%
sensor_info["accel"]["data"]
# Out:
# [[1585869777695, [0.41751695, -0.12954456, 9.846889]],
#  [1585869777774, [0.41683295, -0.13125464, 9.85031]],
#  [1585869777833, [0.4134128, -0.13159664, 9.847573]],
#  [1585869777913, [0.4151229, -0.12475635, 9.849967]],
#  [1585869777972, [0.4151229, -0.12783448, 9.849626]],
#  [1585869778052, [0.40965062, -0.123388305, 9.8486]],
#  [1585869778114, [0.42127916, -0.1329647, 9.851678]],
#  [1585869778189, [0.4137548, -0.12612443, 9.853388]],
#  [1585869778248, [0.41307077, -0.12373032, 9.849283]],
#  [1585869778328, [0.41307077, -0.12373032, 9.851336]],
#  [1585869778387, [0.4233312, -0.12680843, 9.86057]],
#  [1585869778456, [0.41546488, -0.12988658, 9.850995]],
#  [1585869778536, [0.4144388, -0.1237303, 9.849968]],
#  [1585869778594, [0.3980222, -0.10355149, 9.85202]],
#  [1585869778674, [0.4465882, -0.16408798, 9.852363]],
#  [1585869778733, [0.39904827, -0.112101845, 9.852019]],
#  [1585869778813, [0.42435724, -0.12817651, 9.853388]],
# ...

# %%
import keyboard

# %%
keyboard.press_and_release('space')

# %%
 a = [1,2,3]

# %%
a[-1:]
# Out:
# [3]
